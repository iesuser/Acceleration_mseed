# %%
from obspy import read

st = read("export/GO.MTAG.20.HNE_20240722080609.SAC")
st.plot()          # plot waveform
print(st)          # stream info
print(st[0].stats) # SAC header
# Out:
# 1 Trace(s) in Stream:
# GO.MTAG.20.HNE | 2024-07-22T08:06:09.660000Z - 2024-07-22T08:11:09.660000Z | 200.0 Hz, 60001 samples
#          network: GO
#          station: MTAG
#         location: 20
#          channel: HNE
#        starttime: 2024-07-22T08:06:09.660000Z
#          endtime: 2024-07-22T08:11:09.660000Z
#    sampling_rate: 200.0
#            delta: 0.005
#             npts: 60001
#            calib: 1.0
#          _format: SAC
# ...
